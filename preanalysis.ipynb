# %% [markdown]
# # Wstępna analiza danych / Preliminary data analysis

# %%
## python=3.9.13
## pandas, numpy, matplotlib, scikit-learn, jupyter, xlrd

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = 'C:/Users/User/Desktop/MiNI/MAD_II/sem3/Odlewy/data_analysis/dane-żeliwo-ADI/dane.xls'
dataframe = pandas.read_excel(path, header = 9, usecols='K:AM,AT:BF')

# %%
dataframe.head()
# Out:
#   Nr źródła  C [%]  Si [%]  S [%]  P [%]  Mg [%]  Mn [%]  Ni [%]  Cu [%]  \
# 0         1    3.4    2.41  0.017  0.015   0.064    0.15   0.001     0.0
# 1         1    3.4    2.41  0.017  0.015   0.064    0.15   0.001     0.0
# 2         1    3.4    2.41  0.017  0.015   0.064    0.15   0.001     0.0
# 3         1    3.4    2.41  0.017  0.015   0.064    0.15   0.001     0.0
# 4         1    3.4    2.41  0.017  0.015   0.064    0.15   0.001     0.0
#
#    Mo [%]  ...  Twardość Brinella [HB]  Twardość Rockwella [HRC]  \
# 0   0.001  ...                     NaN                       NaN
# 1   0.001  ...                     NaN                       NaN
# 2   0.001  ...                     NaN                       NaN
# 3   0.001  ...                     NaN                       NaN
# 4   0.001  ...                     NaN                       NaN
#
#    Twardość Rockwella [HRA]  Twardość Rockwella [HRB]  Twardość Vickersa [HV]  \
# 0                       NaN                       NaN                     NaN
# 1                       NaN                       NaN                     NaN
# 2                       NaN                       NaN                     NaN
# 3                       NaN                       NaN                     NaN
# 4                       NaN                       NaN                     NaN
#
#    Udarność Charpy [J]  Temperatura pomiaru udarności [˚C]  \
# 0                  NaN                                 NaN
# 1                  NaN                                 NaN
# 2                  NaN                                 NaN
# 3                  NaN                                 NaN
# 4                  NaN                                 NaN
#
#    Udział austenitu % Martensite volume fraction Xα'  \
# 0                28.7                            NaN
# 1                37.5                            NaN
# 2                32.0                            NaN
# 3                28.5                            NaN
# 4                26.2                            NaN
#
#    Retained austenite volume fraction XγR
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 42 columns]

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1508 entries, 0 to 1507
# Data columns (total 42 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Nr źródła                                 1505 non-null   object
#  1   C [%]                                     1441 non-null   float64
#  2   Si [%]                                    1441 non-null   float64
#  3   S [%]                                     1377 non-null   float64
#  4   P [%]                                     1362 non-null   float64
#  5   Mg [%]                                    1278 non-null   float64
#  6   Mn [%]                                    1402 non-null   float64
#  7   Ni [%]                                    1261 non-null   float64
#  8   Cu [%]                                    1225 non-null   float64
#  9   Mo [%]                                    1062 non-null   float64
#  10  Cr [%]                                    475 non-null    float64
#  11  Al [%]                                    413 non-null    float64
#  12  Sn [%]                                    410 non-null    float64
#  13  B [%]                                     401 non-null    float64
#  14  V [%]                                     405 non-null    float64
#  15  Wydzielenia grafitu [mm-2]                532 non-null    float64
#  16  Udział wydzieleń grafitu [%]              137 non-null    float64
#  17  Średnica sferoidów [μm]                   180 non-null    float64
#  18  Wielkość sferoidów                        39 non-null     object
#  19  Nodularity [%]                            166 non-null    float64
#  20  Udział perlitu [%]                        175 non-null    float64
#  21  Udział ferrytu [%]                        196 non-null    float64
#  22  Rm [MPa] (as cast)                        204 non-null    float64
#  23  A5 [%]     (as cast)                      172 non-null    float64
#  24  Minimalna grubość ścianki [mm]            558 non-null    float64
#  25  Temperatura austenityzacji [˚C]           1416 non-null   float64
#  26  Czas austenityzacji [min.]                1389 non-null   float64
#  27  Temperatura przemiany izotermicznej [˚C]  1419 non-null   float64
#  28  Czas przemiany izotermicznej [min.]       1412 non-null   float64
#  29  Rm [MPa]                                  1094 non-null   float64
#  30  R0,2 [MPa]                                844 non-null    float64
#  31  A5 [%]                                    968 non-null    float64
#  32  Twardość Brinella [HB]                    416 non-null    float64
#  33  Twardość Rockwella [HRC]                  435 non-null    float64
#  34  Twardość Rockwella [HRA]                  12 non-null     float64
#  35  Twardość Rockwella [HRB]                  0 non-null      float64
#  36  Twardość Vickersa [HV]                    188 non-null    float64
#  37  Udarność Charpy [J]                       338 non-null    float64
#  38  Temperatura pomiaru udarności [˚C]        312 non-null    float64
#  39  Udział austenitu %                        295 non-null    float64
#  40  Martensite volume fraction Xα'            49 non-null     float64
#  41  Retained austenite volume fraction XγR    212 non-null    float64
# dtypes: float64(40), object(2)
# memory usage: 494.9+ KB

# %%
colnames = list(dataframe.columns)
display(colnames)
# Out:
# ['Nr źródła',
#  'C [%]',
#  'Si [%]',
#  'S [%]',
#  'P [%]',
#  'Mg [%]',
#  'Mn [%]',
#  'Ni [%]',
#  'Cu [%]',
#  'Mo [%]',
#  'Cr [%]',
#  'Al [%]',
#  'Sn [%]',
#  'B [%]',
#  'V [%]',
#  'Wydzielenia grafitu [mm-2]',
#  'Udział wydzieleń grafitu [%]',
#  'Średnica sferoidów [μm]',
#  'Wielkość sferoidów',
#  'Nodularity [%]',
#  'Udział perlitu [%]',
#  'Udział ferrytu [%]',
#  'Rm [MPa] (as cast)',
#  'A5 [%]     (as cast)',
#  'Minimalna grubość ścianki [mm]',
#  'Temperatura austenityzacji [˚C]',
#  'Czas austenityzacji [min.]',
#  'Temperatura przemiany izotermicznej [˚C]',
#  'Czas przemiany izotermicznej [min.]',
#  'Rm [MPa]',
#  'R0,2 [MPa]',
#  'A5 [%]',
#  'Twardość Brinella [HB]',
#  'Twardość Rockwella [HRC]',
#  'Twardość Rockwella [HRA]',
#  'Twardość Rockwella [HRB]',
#  'Twardość Vickersa [HV]',
#  'Udarność Charpy [J]',
#  'Temperatura pomiaru udarności [˚C]',
#  'Udział austenitu %',
#  "Martensite volume fraction Xα'",
#  'Retained austenite volume fraction XγR ']

# %%
pl_eng_dict = {'Nr źródła': 'Id',
 'Wydzielenia grafitu [mm-2]': 'Graphite emission [mm-2]',
 'Udział wydzieleń grafitu [%]': 'Graphite emission share [%]',
 'Średnica sferoidów [μm]': "Spheroid diameter [μm]",
 'Wielkość sferoidów': 'Spheroid size',
 'Udział perlitu [%]': 'Perlite share [%]',
 'Udział ferrytu [%]': 'Ferrite share [%]',
 'Minimalna grubość ścianki [mm]': 'Min wall thickness [mm]',
 'Temperatura austenityzacji [˚C]': 'Austenitization temp [C]',
 'Czas austenityzacji [min.]': 'Austenitization time [min.]',
 'Temperatura przemiany izotermicznej [˚C]': 'Isothermal process temp [C]',
 'Czas przemiany izotermicznej [min.]': 'Isothermal process time [min.]',
 'Twardość Brinella [HB]': 'HB',
 'Twardość Rockwella [HRC]': 'HRC',
 'Twardość Rockwella [HRA]': 'HRA',
 'Twardość Rockwella [HRB]': 'HRB',
 'Twardość Vickersa [HV]': 'HV',
 'Udarność Charpy [J]': 'Charpy impact strength [J]',
 'Temperatura pomiaru udarności [˚C]': 'Impact test temp [C]',
 'Udział austenitu %': 'Austenite share [%]',
 "Martensite volume fraction Xα'": 'Martensite volume',
 'Retained austenite volume fraction XγR ': 'Retained austenite volume'}

# %%
dataframe.rename(columns=pl_eng_dict, inplace=True)
dataframe.head()
# Out:
#   Id  C [%]  Si [%]  S [%]  P [%]  Mg [%]  Mn [%]  Ni [%]  Cu [%]  Mo [%]  \
# 0  1    3.4    2.41  0.017  0.015   0.064    0.15   0.001     0.0   0.001
# 1  1    3.4    2.41  0.017  0.015   0.064    0.15   0.001     0.0   0.001
# 2  1    3.4    2.41  0.017  0.015   0.064    0.15   0.001     0.0   0.001
# 3  1    3.4    2.41  0.017  0.015   0.064    0.15   0.001     0.0   0.001
# 4  1    3.4    2.41  0.017  0.015   0.064    0.15   0.001     0.0   0.001
#
#    ...  HB  HRC  HRA  HRB  HV  Charpy impact strength [J]  \
# 0  ... NaN  NaN  NaN  NaN NaN                         NaN
# 1  ... NaN  NaN  NaN  NaN NaN                         NaN
# 2  ... NaN  NaN  NaN  NaN NaN                         NaN
# 3  ... NaN  NaN  NaN  NaN NaN                         NaN
# 4  ... NaN  NaN  NaN  NaN NaN                         NaN
#
#    Impact test temp [C]  Austenite share [%] Martensite volume  \
# 0                   NaN                 28.7               NaN
# 1                   NaN                 37.5               NaN
# 2                   NaN                 32.0               NaN
# 3                   NaN                 28.5               NaN
# 4                   NaN                 26.2               NaN
#
#    Retained austenite volume
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Zmienne objaśniające / Independent variables

# %%
#data = dataframe.values
#X, y = data[:,:29], data[:,29:]

df_X, df_y = dataframe.iloc[:, 0:29].copy(), dataframe.iloc[:, 29:].copy()

# %%
df_X.head()
# Out:
#   Id  C [%]  Si [%]  S [%]  P [%]  Mg [%]  Mn [%]  Ni [%]  Cu [%]  Mo [%]  \
# 0  1    3.4    2.41  0.017  0.015   0.064    0.15   0.001     0.0   0.001
# 1  1    3.4    2.41  0.017  0.015   0.064    0.15   0.001     0.0   0.001
# 2  1    3.4    2.41  0.017  0.015   0.064    0.15   0.001     0.0   0.001
# 3  1    3.4    2.41  0.017  0.015   0.064    0.15   0.001     0.0   0.001
# 4  1    3.4    2.41  0.017  0.015   0.064    0.15   0.001     0.0   0.001
#
#    ...  Nodularity [%]  Perlite share [%]  Ferrite share [%]  \
# 0  ...             NaN               80.0                NaN
# 1  ...             NaN               80.0                NaN
# 2  ...             NaN               80.0                NaN
# 3  ...             NaN               80.0                NaN
# 4  ...             NaN               80.0                NaN
#
#    Rm [MPa] (as cast)  A5 [%]     (as cast)  Min wall thickness [mm]  \
# 0                 NaN                   NaN                     25.4
# 1                 NaN                   NaN                     25.4
# 2                 NaN                   NaN                     25.4
# 3                 NaN                   NaN                     25.4
# 4                 NaN                   NaN                     25.4
#
#    Austenitization temp [C]  Austenitization time [min.]  \
# 0                     927.0                        120.0
# 1                     927.0                        120.0
# 2                     927.0                        120.0
# 3                     927.0                        120.0
# 4                     927.0                        120.0
#
#   Isothermal process temp [C]  Isothermal process time [min.]
# 0                       400.0                           120.0
# 1                       385.0                           120.0
# 2                       371.0                           120.0
# 3                       357.0                           120.0
# 4                       343.0                           120.0
#
# [5 rows x 29 columns]

# %%
df_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1508 entries, 0 to 1507
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Id                              1505 non-null   object
#  1   C [%]                           1441 non-null   float64
#  2   Si [%]                          1441 non-null   float64
#  3   S [%]                           1377 non-null   float64
#  4   P [%]                           1362 non-null   float64
#  5   Mg [%]                          1278 non-null   float64
#  6   Mn [%]                          1402 non-null   float64
#  7   Ni [%]                          1261 non-null   float64
#  8   Cu [%]                          1225 non-null   float64
#  9   Mo [%]                          1062 non-null   float64
#  10  Cr [%]                          475 non-null    float64
#  11  Al [%]                          413 non-null    float64
#  12  Sn [%]                          410 non-null    float64
#  13  B [%]                           401 non-null    float64
#  14  V [%]                           405 non-null    float64
#  15  Graphite emission [mm-2]        532 non-null    float64
#  16  Graphite emission share [%]     137 non-null    float64
#  17  Spheroid diameter [μm]          180 non-null    float64
#  18  Spheroid size                   39 non-null     object
#  19  Nodularity [%]                  166 non-null    float64
#  20  Perlite share [%]               175 non-null    float64
#  21  Ferrite share [%]               196 non-null    float64
#  22  Rm [MPa] (as cast)              204 non-null    float64
#  23  A5 [%]     (as cast)            172 non-null    float64
#  24  Min wall thickness [mm]         558 non-null    float64
#  25  Austenitization temp [C]        1416 non-null   float64
#  26  Austenitization time [min.]     1389 non-null   float64
#  27  Isothermal process temp [C]     1419 non-null   float64
#  28  Isothermal process time [min.]  1412 non-null   float64
# dtypes: float64(27), object(2)
# memory usage: 341.8+ KB

# %% [markdown]
# ### Supplier info

# %%
supplier_count = df_X.groupby(['Id']).size().reset_index(name='counts')
display(supplier_count)
# Out:
#           Id  counts
# 0          1      12
# 1          2      15
# 2          3      15
# 3          4      48
# 4          5       4
# ..       ...     ...
# 169      200       1
# 170  106/103       1
# 171    52/80       5
# 172    55/77      11
# 173    84/48       5
#
# [174 rows x 2 columns]

# %%
supplier_count.describe()
# Out:
#            counts
# count  174.000000
# mean     8.649425
# std     14.680335
# min      1.000000
# 25%      1.000000
# 50%      4.000000
# 75%      9.000000
# max    108.000000

# %%
#plt.pyplot.boxplot(supplier_count['counts'])
plt.figure(figsize=(7,7))
ax = sns.boxplot(y="counts", data=supplier_count)
plt.show()
# Out:
# c:\Users\User\Anaconda3\envs\odlewy\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ### Analiza składu chemicznego / Chemical composition analysis

# %%
df_X.iloc[:, 1:15].describe()
# Out:
#              C [%]       Si [%]        S [%]        P [%]       Mg [%]  \
# count  1441.000000  1441.000000  1377.000000  1362.000000  1278.000000
# mean      3.562797     2.577160     0.012508     0.033311     0.052736
# std       0.147499     0.283237     0.012952     0.041796     0.079586
# min       3.000000     1.060000     0.000000     0.000000     0.000000
# 25%       3.480000     2.450000     0.007000     0.020000     0.037000
# 50%       3.560000     2.550000     0.010000     0.027000     0.045000
# 75%       3.650000     2.670000     0.014000     0.039000     0.055000
# max       3.970000     3.580000     0.090000     0.340000     0.750000
#
#             Mn [%]       Ni [%]       Cu [%]       Mo [%]      Cr [%]  \
# count  1402.000000  1261.000000  1225.000000  1062.000000  475.000000
# mean      0.260925     0.743539     0.511967     0.141892    0.029718
# std       0.142025     0.711589     0.369622     0.139755    0.068105
# min       0.000000     0.000000     0.000000     0.000000    0.000000
# 25%       0.160000     0.015000     0.070000     0.000000    0.000000
# 50%       0.250000     0.520000     0.540000     0.150000    0.000000
# 75%       0.310000     1.480000     0.800000     0.240000    0.032000
# max       1.230000     5.000000     1.600000     0.630000    0.300000
#
#            Al [%]      Sn [%]       B [%]       V [%]
# count  413.000000  410.000000  401.000000  405.000000
# mean     0.026760    0.001519    0.000329    0.001106
# std      0.340615    0.011960    0.006021    0.011142
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000
# max      4.880000    0.130000    0.120000    0.180000

# %%
plt.figure(figsize=(17,9))
plt.title('Visualization of % share distribution for a given element')
ax = sns.boxplot(x="variable", y="value",data=pandas.melt(df_X.iloc[:, 1:15]))
# Out:
# c:\Users\User\Anaconda3\envs\odlewy\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\User\Anaconda3\envs\odlewy\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\User\Anaconda3\envs\odlewy\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ### Other independent variables

# %%
df_X.iloc[:, 15:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1508 entries, 0 to 1507
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Graphite emission [mm-2]        532 non-null    float64
#  1   Graphite emission share [%]     137 non-null    float64
#  2   Spheroid diameter [μm]          180 non-null    float64
#  3   Spheroid size                   39 non-null     object
#  4   Nodularity [%]                  166 non-null    float64
#  5   Perlite share [%]               175 non-null    float64
#  6   Ferrite share [%]               196 non-null    float64
#  7   Rm [MPa] (as cast)              204 non-null    float64
#  8   A5 [%]     (as cast)            172 non-null    float64
#  9   Min wall thickness [mm]         558 non-null    float64
#  10  Austenitization temp [C]        1416 non-null   float64
#  11  Austenitization time [min.]     1389 non-null   float64
#  12  Isothermal process temp [C]     1419 non-null   float64
#  13  Isothermal process time [min.]  1412 non-null   float64
# dtypes: float64(13), object(1)
# memory usage: 165.1+ KB

# %%
df_X.iloc[:, 15:].describe()
# Out:
#        Graphite emission [mm-2]  Graphite emission share [%]  \
# count                532.000000                   137.000000
# mean                 191.697556                    10.097591
# std                  232.149775                     1.476727
# min                   37.000000                     7.600000
# 25%                  100.000000                     8.800000
# 50%                  150.000000                    10.500000
# 75%                  215.000000                    10.500000
# max                 2170.000000                    13.000000
#
#        Spheroid diameter [μm]  Nodularity [%]  Perlite share [%]  \
# count              180.000000      166.000000         175.000000
# mean                27.518389       89.769277          77.189143
# std                 11.034553        8.577707          18.421896
# min                 12.000000       60.000000          11.000000
# 25%                 23.000000       82.625000          77.700000
# 50%                 23.000000       92.000000          82.700000
# 75%                 32.582500       95.200000          85.000000
# max                 70.000000      100.000000         100.000000
#
#        Ferrite share [%]  Rm [MPa] (as cast)  A5 [%]     (as cast)  \
# count         196.000000          204.000000            172.000000
# mean           22.185204          612.806569              7.910523
# std            14.116556          124.347364              5.376948
# min             9.000000          370.000000              2.810000
# 25%            15.000000          507.000000              4.000000
# 50%            17.300000          576.050000              6.700000
# 75%            24.600000          735.000000             12.100000
# max            88.000000          890.000000             27.700000
#
#        Min wall thickness [mm]  Austenitization temp [C]  \
# count               558.000000               1416.000000
# mean                 26.160932                898.408192
# std                  19.614758                 27.062629
# min                   2.000000                780.000000
# 25%                  12.500000                900.000000
# 50%                  17.000000                900.000000
# 75%                  25.400000                900.000000
# max                  75.000000               1050.000000
#
#        Austenitization time [min.]  Isothermal process temp [C]  \
# count                  1389.000000                  1419.000000
# mean                     96.696184                   339.739253
# std                      39.805360                    42.807269
# min                       1.000000                   200.000000
# 25%                      60.000000                   300.000000
# 50%                      90.000000                   350.000000
# 75%                     120.000000                   370.000000
# max                     300.000000                   454.000000
#
#        Isothermal process time [min.]
# count                     1412.000000
# mean                       108.859065
# std                         71.936337
# min                          0.000000
# 25%                         60.000000
# 50%                        120.000000
# 75%                        120.000000
# max                        480.000000

# %%
print(df_X['Spheroid size'].unique())
# Out:
# [nan 6 5 4 '6 i 7']

# %%
plt.figure(figsize=(17,9))
ax = sns.boxplot(x="variable", y="value",
                 data=pandas.melt(frame=df_X, value_vars=['Graphite emission share [%]', 'Perlite share [%]', 'Ferrite share [%]']))
# Out:
# c:\Users\User\Anaconda3\envs\odlewy\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\User\Anaconda3\envs\odlewy\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\User\Anaconda3\envs\odlewy\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(17,9))
ax = sns.boxplot(x="variable", y="value",data=pandas.melt(df_X.iloc[:, 22:]))
# Out:
# c:\Users\User\Anaconda3\envs\odlewy\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\User\Anaconda3\envs\odlewy\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\User\Anaconda3\envs\odlewy\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ## Zmienne objaśniane / Target variables

# %%
df_y.head()
# Out:
#    Rm [MPa]  R0,2 [MPa]  A5 [%]  Twardość Brinella [HB]  \
# 0     585.0       480.0     NaN                     NaN
# 1     701.0       636.0     NaN                     NaN
# 2    1062.0       861.0    10.5                     NaN
# 3    1105.0       946.0     9.6                     NaN
# 4    1185.0       989.0     NaN                     NaN
#
#    Twardość Rockwella [HRC]  Twardość Rockwella [HRA]  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    Twardość Rockwella [HRB]  Twardość Vickersa [HV]  Udarność Charpy [J]  \
# 0                       NaN                     NaN                  NaN
# 1                       NaN                     NaN                  NaN
# 2                       NaN                     NaN                  NaN
# 3                       NaN                     NaN                  NaN
# 4                       NaN                     NaN                  NaN
#
#    Temperatura pomiaru udarności [˚C]  Udział austenitu %  \
# 0                                 NaN                28.7
# 1                                 NaN                37.5
# 2                                 NaN                32.0
# 3                                 NaN                28.5
# 4                                 NaN                26.2
#
#    Martensite volume fraction Xα'  Retained austenite volume fraction XγR
# 0                             NaN                                      NaN
# 1                             NaN                                      NaN
# 2                             NaN                                      NaN
# 3                             NaN                                      NaN
# 4                             NaN                                      NaN

# %%
df_y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1508 entries, 0 to 1507
# Data columns (total 13 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Rm [MPa]                                 1094 non-null   float64
#  1   R0,2 [MPa]                               844 non-null    float64
#  2   A5 [%]                                   968 non-null    float64
#  3   Twardość Brinella [HB]                   416 non-null    float64
#  4   Twardość Rockwella [HRC]                 435 non-null    float64
#  5   Twardość Rockwella [HRA]                 12 non-null     float64
#  6   Twardość Rockwella [HRB]                 0 non-null      float64
#  7   Twardość Vickersa [HV]                   188 non-null    float64
#  8   Udarność Charpy [J]                      338 non-null    float64
#  9   Temperatura pomiaru udarności [˚C]       312 non-null    float64
#  10  Udział austenitu %                       295 non-null    float64
#  11  Martensite volume fraction Xα'           49 non-null     float64
#  12  Retained austenite volume fraction XγR   212 non-null    float64
# dtypes: float64(13)
# memory usage: 153.3 KB

# %%
df_y.describe()
# Out:
#           Rm [MPa]   R0,2 [MPa]      A5 [%]  Twardość Brinella [HB]  \
# count  1094.000000   844.000000  968.000000              416.000000
# mean   1095.299625   841.605687    6.518512              333.068510
# std     247.872392   240.767604    4.190676               63.376505
# min       0.000000     0.000000    0.000000              218.000000
# 25%     950.250000   700.000000    3.200000              290.000000
# 50%    1084.000000   828.000000    6.000000              325.500000
# 75%    1230.825000   953.750000    9.500000              373.250000
# max    2000.000000  1630.000000   33.000000              534.000000
#
#        Twardość Rockwella [HRC]  Twardość Rockwella [HRA]  \
# count                435.000000                 12.000000
# mean                  38.264874                 57.833333
# std                    5.961462                  7.755741
# min                   22.800000                 48.000000
# 25%                   34.000000                 50.000000
# 50%                   37.000000                 58.500000
# 75%                   43.000000                 64.500000
# max                   58.000000                 67.000000
#
#        Twardość Rockwella [HRB]  Twardość Vickersa [HV]  Udarność Charpy [J]  \
# count                       0.0              188.000000           338.000000
# mean                        NaN              334.569149            70.102574
# std                         NaN              125.010610            40.207092
# min                         NaN                0.000000             2.670000
# 25%                         NaN              305.750000            38.000000
# 50%                         NaN              344.000000            69.500000
# 75%                         NaN              400.000000           102.000000
# max                         NaN              632.000000           157.000000
#
#        Temperatura pomiaru udarności [˚C]  Udział austenitu %  \
# count                          312.000000          295.000000
# mean                            10.600962           25.432271
# std                             39.936720           13.663103
# min                           -100.000000            0.000000
# 25%                            -10.000000           14.700000
# 50%                             21.000000           27.000000
# 75%                             21.000000           34.950000
# max                            136.200000           83.000000
#
#        Martensite volume fraction Xα'  Retained austenite volume fraction XγR
# count                       49.000000                               212.000000
# mean                        12.718429                                21.301274
# std                         17.226564                                11.568671
# min                          0.000000                                 0.000000
# 25%                          0.001000                                13.000000
# 50%                          3.000000                                19.160000
# 75%                         20.000000                                28.000000
# max                         64.000000                                52.000000

# %% [markdown]
# Ideas:
# * Group by supplier
# * Pick one hardness, convert the rest to that - find tables in excel online
